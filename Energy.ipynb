# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('COMED_hourly.csv.zip' ,parse_dates=['Datetime'],index_col='Datetime')

# %%
data['COMED_MW']= pd.to_numeric(data['COMED_MW'], errors='coerce')

# %%
data['COMED_MW']= data['COMED_MW'].fillna(0)

# %%
cost_per_Mwh= 100

# %%
data_sample = data.resample('D').sum()
data_sample['Operational_Costs']= data_sample['COMED_MW']*cost_per_Mwh

# %%
print(data_sample[['COMED_MW','Operational_Costs']])
# Out:
#             COMED_MW  Operational_Costs
# Datetime
# 2011-01-01  241162.0         24116200.0
# 2011-01-02  270137.0         27013700.0
# 2011-01-03  290823.0         29082300.0
# 2011-01-04  299994.0         29999400.0
# 2011-01-05  308524.0         30852400.0
# ...              ...                ...
# 2018-07-30  296519.0         29651900.0
# 2018-07-31  295933.0         29593300.0
# 2018-08-01  307690.0         30769000.0
# 2018-08-02  329641.0         32964100.0
# 2018-08-03   13335.0          1333500.0
#
# [2772 rows x 2 columns]

# %%
data_sample.to_csv('operational_Cost.csv')

# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting plotly
#   Downloading plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in c:\users\harsh\appdata\roaming\python\python312\site-packages (from plotly) (24.2)
# Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/19.1 MB 5.6 MB/s eta 0:00:04
#    -- ------------------------------------- 1.0/19.1 MB 5.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.6/19.1 MB 4.3 MB/s eta 0:00:04
#    ------ --------------------------------- 2.9/19.1 MB 3.6 MB/s eta 0:00:05
#    ------- -------------------------------- 3.4/19.1 MB 3.2 MB/s eta 0:00:05
#    ------- -------------------------------- 3.7/19.1 MB 3.2 MB/s eta 0:00:05
#    --------- ------------------------------ 4.7/19.1 MB 3.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.5/19.1 MB 3.3 MB/s eta 0:00:05
#    ------------- -------------------------- 6.3/19.1 MB 3.3 MB/s eta 0:00:04
#    -------------- ------------------------- 7.1/19.1 MB 3.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 7.9/19.1 MB 3.4 MB/s eta 0:00:04
#    ------------------ --------------------- 8.7/19.1 MB 3.4 MB/s eta 0:00:04
#    ------------------- -------------------- 9.4/19.1 MB 3.5 MB/s eta 0:00:03
#    --------------------- ------------------ 10.2/19.1 MB 3.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 11.0/19.1 MB 3.5 MB/s eta 0:00:03
#    ------------------------ --------------- 11.8/19.1 MB 3.5 MB/s eta 0:00:03
#    -------------------------- ------------- 12.8/19.1 MB 3.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 13.6/19.1 MB 3.6 MB/s eta 0:00:02
#    ------------------------------ --------- 14.4/19.1 MB 3.6 MB/s eta 0:00:02
#    ------------------------------- -------- 14.9/19.1 MB 3.6 MB/s eta 0:00:02
#    --------------------------------- ------ 15.7/19.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 16.5/19.1 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 17.3/19.1 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 18.1/19.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  18.9/19.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 19.1/19.1 MB 3.5 MB/s eta 0:00:00
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.24.1 tenacity-9.0.0
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.graph_objects as go

# %%
pip install nbformat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nbformat
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting fastjsonschema>=2.15 (from nbformat)
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting jsonschema>=2.6 (from nbformat)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from nbformat) (5.14.3)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat)
#   Downloading rpds_py-0.22.3-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\harsh\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.22.3-cp312-cp312-win_amd64.whl (235 kB)
# Installing collected packages: fastjsonschema, rpds-py, attrs, referencing, jsonschema-specifications, jsonschema, nbformat
# Successfully installed attrs-24.2.0 fastjsonschema-2.21.1 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 nbformat-5.10.4 referencing-0.35.1 rpds-py-0.22.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.io as pio
pio.renderers.default = 'browser'

# %%
fig.add_trace(go.Scatter(x=data_sample.index,
                         y=data_sample['Operational_Costs'],
                         mode='lines',
                         name= 'Operational Costs ($)',
                         line= dict(color='green')))

# %%
fig.update_layout(title = "Energy Consumption and operational Costs over Time",
                  xaxis_title="DateTime",
                  yaxis_title="Value",
                  legend_title ="Metrics",
                  template= "plotly_dark",
                  xaxis = dict(tickformat= "%Y-%m-%d"),
                  height= 600,
                  width= 1000)

# %%
fig.show()

# %%
import plotly.graph_objects as go
